# %%
import agents_SBM_generate
import matplotlib.pyplot as plt
# Out:
# Could not load sparse_dot_mkl. Will use scipy.sparse for matrix products.

# %% [markdown]
# ## Network 0

# %%
# Example usage:
t_start = 0
delta1 = 150
t_end = 2 * delta1

num_cores = 4

block_mod_func = agents_SBM_generate.make_step_block_probs(delta1,  num_cores=num_cores, basis_num_communities = 2, powers_num_communities = [2, 1], list_p_within_community=[49/50] * 2)
net = agents_SBM_generate.generate_agents_SBM(block_mod_func=block_mod_func, inter_tau= 25, activ_tau= 5, n_per_group=10, n_groups = num_cores, t_start= t_start, t_end=t_end)
# Out:
# running simulation
# ...
# PID  202677  :  merged  634  events
# PID  202677  :  merged  0  events

# %%
plt.matshow(net.compute_static_adjacency_matrix(start_time=0, end_time=150).toarray())
#plt.savefig('/home/b/skoove/Desktop/growing300/aggregating1.png', format='png', dpi=300)
plt.matshow(net.compute_static_adjacency_matrix(start_time=150, end_time=300).toarray())

# %%
#net.save('evolving_SBM_net0')

# %% [markdown]
# ## Network 1

# %%
# Example usage:
t_start = 0
delta1 = 100
t_end = 3 * delta1

num_cores = 8

block_mod_func = agents_SBM_generate.make_step_block_probs(delta1,  num_cores=num_cores, basis_num_communities = 2, powers_num_communities = [3, 2, 1], list_p_within_community=[49/50] * 3)
net = agents_SBM_generate.generate_agents_SBM(block_mod_func=block_mod_func, inter_tau= 25, activ_tau= 5, n_per_group=10, n_groups = num_cores, t_start= t_start, t_end=t_end)
# Out:
# running simulation
# PID  1567438  :  merged  1216  events
# PID  1567438  :  merged  0  events

# %%
plt.matshow(net.compute_static_adjacency_matrix(start_time=0, end_time=100).toarray())
#plt.savefig('/home/b/skoove/Desktop/growing300/aggregating1.png', format='png', dpi=300)
plt.matshow(net.compute_static_adjacency_matrix(start_time=100, end_time=200).toarray())
plt.matshow(net.compute_static_adjacency_matrix(start_time=200, end_time=300).toarray())

# %%
net.times
# Out:
# Index([0.16855577355594312, 0.19018484441794228, 0.30693990432795293,
#        0.31631188211241645,  0.4712415279846169, 0.49073442619625596,
#         0.5408357413006142,  0.5614230796818234,  0.5902814812639374,
#         0.6822474443313595,
#        ...
#         299.24940471796594,   299.2751778458969,   299.4818296482629,
#         299.56881752143465,  299.86694857182687,   299.8784489001435,
#         299.94481945813726,  299.95974677671256,  299.96778095099677,
#         300.04091569377556],
#       dtype='float64', name='times', length=6484)

# %%
#net.save('agents_SBM_net1')

# %% [markdown]
# ## Network 2

# %%
# Example usage:
t_start = 0
delta1 = 100
t_end = 3 * delta1

num_cores = 8

block_mod_func = agents_SBM_generate.make_step_block_probs(delta1,  num_cores=num_cores, basis_num_communities = 2, powers_num_communities = [3, 1, 2], list_p_within_community=[49/50] * 3)
net = agents_SBM_generate.generate_agents_SBM(block_mod_func=block_mod_func, inter_tau= 25, activ_tau= 5, n_per_group=10, n_groups = num_cores, t_start= t_start, t_end=t_end)
# Out:
# running simulation
# ...
# PID  1567438  :  merged  1043  events
# PID  1567438  :  merged  0  events

# %%
plt.matshow(net.compute_static_adjacency_matrix(start_time=0, end_time=100).toarray())
#plt.savefig('/home/b/skoove/Desktop/growing300/aggregating1.png', format='png', dpi=300)
plt.matshow(net.compute_static_adjacency_matrix(start_time=100, end_time=200).toarray())
plt.matshow(net.compute_static_adjacency_matrix(start_time=200, end_time=300).toarray())

# %%
#net.save('agents_SBM_net2')

# %% [markdown]
# ## Network 3

# %%
# Example usage:
t_start = 0
delta1 = 100
t_end = 3 * delta1

num_cores = 8

block_mod_func = agents_SBM_generate.make_step_block_probs(delta1,  num_cores=num_cores, basis_num_communities = 2, powers_num_communities = [2, 3, 1], list_p_within_community=[49/50] * 3)
net = agents_SBM_generate(block_mod_func=block_mod_func, inter_tau= 25, activ_tau= 5, n_per_group=10, n_groups = num_cores, t_start= t_start, t_end=t_end)
# Out:
# running simulation
# ...
# PID  1567438  :  merged  1169  events
# PID  1567438  :  merged  0  events

# %%
plt.matshow(net.compute_static_adjacency_matrix(start_time=0, end_time=100).toarray())
#plt.savefig('/home/b/skoove/Desktop/growing300/aggregating1.png', format='png', dpi=300)
plt.matshow(net.compute_static_adjacency_matrix(start_time=100, end_time=200).toarray())
plt.matshow(net.compute_static_adjacency_matrix(start_time=200, end_time=300).toarray())

# %%
#net.save('agents_SBM_net3')

# %% [markdown]
# ### Network4

# %%
# Example usage:
t_start = 0
delta1 = 150
t_end = 2 * delta1

num_cores = 4

block_mod_func = agents_SBM_generate.make_step_block_probs(delta1,  num_cores=num_cores, basis_num_communities = 2, powers_num_communities = [1, 2], list_p_within_community=[49/50] * 2)
net = agents_SBM_generate.generate_evolving_SBM(block_mod_func=block_mod_func, inter_tau= 25, activ_tau= 5, n_per_group=10, n_groups = num_cores, t_start= t_start, t_end=t_end)
# Out:
# running simulation
# PID  1567438  :  merged  698  events
# PID  1567438  :  merged  0  events

# %%
plt.matshow(net.compute_static_adjacency_matrix(start_time=0, end_time=150).toarray())
#plt.savefig('/home/b/skoove/Desktop/growing300/aggregating1.png', format='png', dpi=300)
plt.matshow(net.compute_static_adjacency_matrix(start_time=150, end_time=300).toarray())

# %%
#net.save('agents_SBM_net4')
